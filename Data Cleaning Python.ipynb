# %% [markdown]
# # Busniess Objective

# %% [markdown]
#  data need be cleaned and ready to create a dashboard that compares and informs stakeholders about Data Science Employment.

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Collection

# %%
df=pd.read_csv("DataScientist.csv")
df
# Out:
#       Unnamed: 0  index                                          Job Title  \
# 0              0      0                              Senior Data Scientist
# 1              1      1                  Data Scientist, Product Analytics
# 2              2      2                               Data Science Manager
# 3              3      3                                       Data Analyst
# 4              4      4                             Director, Data Science
# ...          ...    ...                                                ...
# 3904        3904   4375                                  AWS Data Engineer
# 3905        3905   4376                              Data Analyst â Junior
# 3906        3906   4377                   Security Analytics Data Engineer
# 3907        3907   4378                   Security Analytics Data Engineer
# 3908        3908   4379  Patient Safety Physician or Safety Scientist -...
#
#                    Salary Estimate  \
# ...

# %% [markdown]
# # Understanding Data

# %%
# to see first five rows
df.head(5)
# Out:
#    Unnamed: 0  index                          Job Title  \
# 0           0      0              Senior Data Scientist
# 1           1      1  Data Scientist, Product Analytics
# 2           2      2               Data Science Manager
# 3           3      3                       Data Analyst
# 4           4      4             Director, Data Science
#
#                 Salary Estimate  \
# 0  $111K-$181K (Glassdoor est.)
# 1  $111K-$181K (Glassdoor est.)
# 2  $111K-$181K (Glassdoor est.)
# 3  $111K-$181K (Glassdoor est.)
# 4  $111K-$181K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1  At Noom, we use scientifically proven methods ...     4.5
# 2  Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
# 3  Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4  Director, Data Science - (200537)\nDescription...     3.4
#
# ...

# %%
# to see last five rows
df.tail(5)
# Out:
#       Unnamed: 0  index                                          Job Title  \
# 3904        3904   4375                                  AWS Data Engineer
# 3905        3905   4376                              Data Analyst â Junior
# 3906        3906   4377                   Security Analytics Data Engineer
# 3907        3907   4378                   Security Analytics Data Engineer
# 3908        3908   4379  Patient Safety Physician or Safety Scientist -...
#
#                   Salary Estimate  \
# 3904  $55K-$112K (Glassdoor est.)
# 3905  $55K-$112K (Glassdoor est.)
# 3906  $55K-$112K (Glassdoor est.)
# 3907  $55K-$112K (Glassdoor est.)
# 3908  $55K-$112K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 3904  About Us\n\nTachyon Technologies is a Digital ...     4.4
# 3905  Job description\nInterpret data, analyze resul...     5.0
# 3906  Job DescriptionThe Security Analytics Data Eng...     3.8
# ...

# %%
# to see sample five rows
df.sample(5)
# Out:
#       Unnamed: 0  index                                          Job Title  \
# 2032        2032   2240                                Senior Data Analyst
# 464          464    534              Business Intelligence Analyst - Entry
# 1152        1152   1297                                   MDM Data Analyst
# 184          184    196                            Deployed Data Scientist
# 3340        3340   3676  Quantum Principal Data Scientist (Industrial-D...
#
#                    Salary Estimate  \
# 2032   $74K-$140K (Glassdoor est.)
# 464   $134K-$218K (Glassdoor est.)
# 1152   $55K-$117K (Glassdoor est.)
# 184   $156K-$254K (Glassdoor est.)
# 3340    $38K-$68K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 2032  Who we’re looking for\nEarth Class Mail is sea...     4.5
# 464   Business Intelligence Analyst - Los Angeles, C...     3.8
# 1152  Arthur Lawrence is urgently looking for MDM Da...     4.1
# ...

# %%
# to see data shape
df.shape
# Out:
# (3909, 17)

# %%
# to see columns name
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Job Title', 'Salary Estimate',
#        'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters',
#        'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue',
#        'Competitors', 'Easy Apply'],
#       dtype='object')

# %%
# to see data types
df.dtypes
# Out:
# Unnamed: 0             int64
# index                  int64
# Job Title             object
# Salary Estimate       object
# Job Description       object
# Rating               float64
# Company Name          object
# Location              object
# Headquarters          object
# Size                  object
# Founded                int64
# Type of ownership     object
# Industry              object
# Sector                object
# Revenue               object
# Competitors           object
# Easy Apply            object
# dtype: object

# %%
# to see basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3909 entries, 0 to 3908
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         3909 non-null   int64
#  1   index              3909 non-null   int64
#  2   Job Title          3909 non-null   object
#  3   Salary Estimate    3909 non-null   object
#  4   Job Description    3909 non-null   object
#  5   Rating             3909 non-null   float64
#  6   Company Name       3909 non-null   object
#  7   Location           3909 non-null   object
#  8   Headquarters       3909 non-null   object
#  9   Size               3909 non-null   object
#  10  Founded            3909 non-null   int64
#  11  Type of ownership  3909 non-null   object
#  12  Industry           3909 non-null   object
#  13  Sector             3909 non-null   object
#  14  Revenue            3909 non-null   object
#  15  Competitors        3909 non-null   object
# ...

# %% [markdown]
# # Data Cleaning

# %%
# firstly drop unwanted columns
df.drop(columns=['Unnamed: 0','Size','Competitors'],axis=1,inplace=True)

# %%
# drop easy Apply columns
df.drop(columns=['Easy Apply'],axis=1,inplace=True)

# %%
# drop Revenue columns
df.drop(columns=['Revenue'],axis=1,inplace=True)

# %%
# drop Founded columns
df.drop(columns=['Founded'],axis=1,inplace=True)

# %% [markdown]
# # Clean Sector  Columns Data

# %%
df['Sector'].value_counts()
# Out:
# Information Technology                1124
# Business Services                      679
# -1                                     546
# Biotech & Pharmaceuticals              293
# Finance                                270
# Health Care                            197
# Insurance                              109
# Education                              101
# Manufacturing                           87
# Government                              82
# Media                                   75
# Retail                                  72
# Accounting & Legal                      71
# Aerospace & Defense                     37
# Oil, Gas, Energy & Utilities            34
# Telecommunications                      21
# Consumer Services                       20
# Non-Profit                              18
# Construction, Repair & Maintenance      16
# Transportation & Logistics              16
# Real Estate                             12
# Arts, Entertainment & Recreation        10
# ...

# %%
df['Sector']=df['Sector'].replace('-1','Other')

# %%
df['Industry']=df['Industry'].replace('-1','Other')

# %% [markdown]
# # Clean Types of Ownership Columns

# %%
df['Type of ownership'].value_counts()
# Out:
# Company - Private                 1933
# Company - Public                  1114
# -1                                 229
# Nonprofit Organization             207
# Subsidiary or Business Segment     160
# Government                          91
# College / University                77
# Unknown                             38
# Contract                            17
# Hospital                            16
# Private Practice / Firm             12
# School / School District             5
# Other Organization                   5
# Self-employed                        4
# Franchise                            1
# Name: Type of ownership, dtype: int64

# %%
df['Type of ownership']=df['Type of ownership'].replace('-1','Other')

# %%
df['Type of ownership']=df['Type of ownership'].str.replace('Company -','')

# %%
df['Type of ownership']=df['Type of ownership'].str.replace('Subsidiary or ','')

# %%
df['Type of ownership']=df['Type of ownership'].str.replace('Private Practice / Firm','Private Practice')

# %%
df.head(2)
# Out:
#    index                          Job Title               Salary Estimate  \
# 0      0              Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1      1  Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
#
#                                      Job Description  Rating  Company Name  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5   Hopper\n3.5
# 1  At Noom, we use scientifically proven methods ...     4.5  Noom US\n4.5
#
#        Location      Headquarters Type of ownership  \
# 0  New York, NY  Montreal, Canada           Private
# 1  New York, NY      New York, NY           Private
#
#                     Industry             Sector
# 0            Travel Agencies   Travel & Tourism
# 1  Health, Beauty, & Fitness  Consumer Services

# %%
df['Headquarters'].value_counts()
# Out:
# New York     302
# Unknown      240
# San Diego    179
# Chicago      158
# Austin       106
#             ...
# Ruislip        1
# Whippany       1
# Branford       1
# Elverson       1
# Andover        1
# Name: Headquarters, Length: 524, dtype: int64

# %%
df['Headquarters']=df['Headquarters'].replace('-1','Unknown')

# %%
df['Headquarters']=df['Headquarters'].str.split(',').str[0]

# %%
df['Location'].value_counts()
# Out:
# Austin                   345
# Chicago                  330
# San Diego                304
# New York                 303
# Houston                  219
#                         ...
# National City              1
# Chula Vista                1
# Nassau Bay                 1
# West University Place      1
# Hilliard                   1
# Name: Location, Length: 185, dtype: int64

# %%
df['Location']=df['Location'].str.split(',').str[0]

# %%
df['Company Name'].value_counts()
# Out:
# Apple\n4.1                               60
# IBM\n3.7                                 57
# Amazon\n3.9                              47
# Staffigo Technical Services, LLC\n5.0    28
# Facebook\n4.5                            25
#                                          ..
# Crawford Thomas Recruiting\n5.0           1
# Corporate\n2.0                            1
# Infogium Technologies, LLC\n5.0           1
# Microtek Digital LLC                      1
# Data Resource Technologies\n4.0           1
# Name: Company Name, Length: 2075, dtype: int64

# %%
df=df1.copy()

# %%
df1['Company Name'] = df1['Company Name'].apply(lambda x:x.split()[0])

# %%
df1['Company Name'].value_counts()
# Out:
# The            66
# IBM            61
# Apple          60
# Amazon         47
# University     33
#                ..
# Itbrainiac      1
# PinnacleART     1
# Sunmerge        1
# Hexagon         1
# ComResource     1
# Name: Company Name, Length: 1764, dtype: int64

# %%
df1['Rating'] = df1['Rating'].replace([-1],np.nan)

# %%
df1['Rating'].isnull().sum()
# Out:
# 0

# %%
round(df1['Rating'].mean(),1)
# Out:
# 3.8

# %%
df1['Rating']=df1['Rating'].fillna(round(df1['Rating'].mean(),1))

# %%
df=df1.copy()

# %%
df1.head(2)
# Out:
#    index                          Job Title Salary Estimate  \
# 0      0              Senior Data Scientist     $111K-$181K
# 1      1  Data Scientist, Product Analytics     $111K-$181K
#
#                                      Job Description  Rating Company Name  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5       Hopper
# 1  At Noom, we use scientifically proven methods ...     4.5         Noom
#
#    Location Headquarters Type of ownership                   Industry  \
# 0  New York     Montreal           Private            Travel Agencies
# 1  New York     New York           Private  Health, Beauty, & Fitness
#
#               Sector  Min_Salary  Max_Salary
# 0   Travel & Tourism    111000.0    181000.0
# 1  Consumer Services    111000.0    181000.0

# %%
df1['Salary Estimate'] = df1['Salary Estimate'].apply(lambda x:x.split()[0])

# %%
df1['Min_Salary'] = df1['Salary Estimate'].str.split('-').str[0]
df1['Max_Salary'] = df1['Salary Estimate'].str.split('-').str[1]

# %%
df1['Min_Salary'] = df1['Min_Salary'].str.replace('$','')
df1['Max_Salary'] = df1['Max_Salary'].str.replace('$','')

# %%
df1['Min_Salary'] = df1['Min_Salary'].str.replace('K','')
df1['Max_Salary'] = df1['Max_Salary'].str.replace('K','')

# %%
df1['Max_Salary'] = df1['Max_Salary'].str.split('(').str[0]

# %%
def con(x):
    if 'K' in x:
        x = x.replace('K','')
        x = float(x) *1000
        x = int(x)
        return x

# %%
df1['Min_Salary'] = df1['Min_Salary'].apply(con)

# %%
df1['Max_Salary'] = df1['Max_Salary'].apply(con)

# %%
df['Min_Salary'].mode[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Min_Salary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1['Min_Salary'] = df1['Min_Salary'].fillna(df1['Min_Salary'].median())
df1['Max_Salary'] = df1['Max_Salary'].fillna(df1['Max_Salary'].median())

# %%
df1.isnull().sum()
# Out:
# index                0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Type of ownership    0
# Industry             0
# Sector               0
# Min_Salary           0
# Max_Salary           0
# dtype: int64

# %%
df1['Min_Salary'] = df1['Min_Salary'].astype('int')
df1['Max_Salary'] = df1['Max_Salary'].astype('int')

# %%
df=df1.copy()

# %%
df
# Out:
#       index                                          Job Title  \
# 0         0                              Senior Data Scientist
# 1         1                  Data Scientist, Product Analytics
# 2         2                               Data Science Manager
# 3         3                                       Data Analyst
# 4         4                             Director, Data Science
# ...     ...                                                ...
# 3904   4375                                  AWS Data Engineer
# 3905   4376                              Data Analyst â Junior
# 3906   4377                   Security Analytics Data Engineer
# 3907   4378                   Security Analytics Data Engineer
# 3908   4379  Patient Safety Physician or Safety Scientist -...
#
#      Salary Estimate                                    Job Description  \
# 0        $111K-$181K  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...
# ...

# %%
df['Job Title'].value_counts()
# Out:
# Data Scientist                                               412
# Data Engineer                                                306
# Data Analyst                                                 296
# Senior Data Scientist                                        118
# Machine Learning Engineer                                     61
#                                                             ...
# Vertical Lift Data Exploitation Analyst                        1
# PD Downstream Sr Scientist                                     1
# Immunoassay Data Scientist                                     1
# QC Analytical Scientist or Senior QC Analytical Scientist      1
# Patient Safety Physician or Safety Scientist                   1
# Name: Job Title, Length: 1386, dtype: int64

# %%
df['Job Title'] = df['Job Title'].apply(lambda x:x.join(x.split(',')[:1]))
df['Job Title'] = df['Job Title'].apply(lambda x:x.join(x.split('/')[:1]))
df['Job Title'] = df['Job Title'].apply(lambda x:x.join(x.split(' - ')[:1]))

# %%
df.head(2)
# Out:
#    index              Job_Title  \
# 0      0  Senior Data Scientist
# 1      1         Data Scientist
#
#                                      Job Description  Rating Company_Name  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5       Hopper
# 1  At Noom, we use scientifically proven methods ...     4.5         Noom
#
#    Location Headquarters Ownership                   Industry  \
# 0  New York     Montreal   Private            Travel Agencies
# 1  New York     New York   Private  Health, Beauty, & Fitness
#
#               Sector  Min_Salary  Max_Salary
# 0   Travel & Tourism      111000      181000
# 1  Consumer Services      111000      181000

# %%
df.drop(columns=['Salary Estimate'],axis=1,inplace=True)

# %%
df.rename(columns={'Job Title':'Job_Title','Company Name':'Company_Name','Type of ownership':'Ownership'},inplace=True)

# %%
df['Job Description']
# Out:
# 0       ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...
# 1       At Noom, we use scientifically proven methods ...
# 2       Decode_M\n\nhttps://www.decode-m.com/\n\nData ...
# 3       Sapphire Digital seeks a dynamic and driven mi...
# 4       Director, Data Science - (200537)\nDescription...
#                               ...
# 3904    About Us\n\nTachyon Technologies is a Digital ...
# 3905    Job description\nInterpret data, analyze resul...
# 3906    Job DescriptionThe Security Analytics Data Eng...
# 3907    The Security Analytics Data Engineer will inte...
# 3908    Help us transform patients' lives.\nAt UCB, we...
# Name: Job Description, Length: 3909, dtype: object

# %%
skills_set = ['sql','python','power bi','tableau','excel',' r ']
#using for loop to frequency of each skills 
for skills in skills_set:
  print('Number of job that requires',skills,':',len(df[
            (df['Job Description'].str.contains(skills, case = False)) & 
            (df['Job_Title']=='Data Analyst')]))
# Out:
# Number of job that requires sql : 216
# Number of job that requires python : 85
# Number of job that requires power bi : 37
# Number of job that requires tableau : 78
# Number of job that requires excel : 176
# Number of job that requires  r  : 17

# %%
df.to_csv(r"C:\Users\Rakib Hasan\Downloads\DataScientist.csv\clean.csv")
